# %% [markdown]
# Note: The pictures I used to train this CV is not fully mine. I did put a few pictures(around 100 something) that are taken from the cabinet prototype. but the rest are from the internet

# %% [markdown]
# To check if my google collab's GPU is available

# %%
# !nvidia-smi
# Out:
# Wed Jul 10 11:35:54 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   49C    P0              28W /  72W |    733MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325
# Receiving objects: 100% (325/325), 2.25 MiB | 27.06 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.3 MB/s eta 0:00:00
# ERROR: Operation cancelled by user
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 11.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %% [markdown]
# to mount google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# to load all the yolov9 pretrained models

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325
# Receiving objects: 100% (325/325), 2.25 MiB | 24.47 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 44.9 MB/s eta 0:00:00

# %% [markdown]
# To access the functions and classes for YOLO model training

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.0/800.0 kB 20.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO("yolov9m.pt")

# Display model information (optional)
model.info()
# Out:
# ...
# 100%|██████████| 39.1M/39.1M [00:00<00:00, 274MB/s]
# YOLOv9m summary: 603 layers, 20216160 parameters, 0 gradients, 77.9 GFLOPs
# (603, 20216160, 0, 77.86652160000001)

# %% [markdown]
# train model

# %%
'''
    I did 16 batches as it is the least amount of time to train the CV and the max amount of batches before I run out of ram in my gpu in google collab
'''
results = model.train(data="/content/gdrive/MyDrive/Colab Notebooks/Data/Iot Sys food/Food Pics/Smart shopping cart.v1i.yolov9/data.yaml" , project = "/content/gdrive/MyDrive/yolov9_iot2/", epochs=25 , batch = 16) # project is to store all of my yolo model data(like the CV model and confusion matrixes). data is where you store all your images
model.export(format="onnx") # just in case i needed the model in onxx
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# predict using model

# %%
from PIL import Image
from ultralytics import YOLO

def predict(model_path , image):
  model = YOLO(model_path)
  predict_results = model.predict(image, imgsz = 640 , conf = 0.6 , save = True) # to predict the picture and to determine if any object inside is 60%
  for r in predict_results:
    boxes = r.boxes  # Boxes object for bbox outputs

    predicted_food = boxes.cls.tolist()
    predicted_start_end = boxes.xyxy.tolist() # returns the food's (x, y)
    predicted_conf = boxes.conf.tolist()
    '''
    can be seen in data.yaml.
      Nutella = 0
      Pepsi = 1
      Pringles = 2
    '''
    all_items = {
                "Nutella":0,
                "Pepsi":0 ,
                "Pringles":0
                }
    for i in range(len(predicted_food)):
        # 1 loop for every trash in predicted trash
        print(f"predicted_food: {predicted_food[i]}")
        if predicted_food[i] == 0:
          all_items["Nutella"] += 1
        elif predicted_food[i] == 1:
          all_items["Pepsi"] += 1
        elif predicted_food[i] == 2:
          all_items["Pringles"] += 1
        print(f"predicted_conf: {predicted_conf[i]}")
        print(f"predicted_start_end: {predicted_start_end[i]}")
    print(f"all items: {all_items}")
    return all_items

image = Image.open("/content/gdrive/MyDrive/Colab Notebooks/Data/Iot Sys food/stress_test_model_pics/20240709_230702food.jpg")
print(predict("/content/gdrive/MyDrive/yolov9_iot2/train2/weights/best.pt" , image))
# Out:
# 0: 480x640 1 Nutella, 1 Pepsi, 1 Pringles, 347.2ms
# Speed: 28.8ms preprocess, 347.2ms inference, 896.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# predicted_food: 0.0
# predicted_conf: 0.9607598781585693
# predicted_start_end: [116.70584106445312, 476.0417175292969, 563.6051025390625, 870.9361572265625]
# predicted_food: 1.0
# predicted_conf: 0.8340334296226501
# predicted_start_end: [823.3218383789062, 0.0, 1143.926025390625, 256.39141845703125]
# predicted_food: 2.0
# predicted_conf: 0.6824359893798828
# predicted_start_end: [1.6680908203125, 0.0, 808.3062744140625, 646.4971923828125]
# all items: {'Nutella': 1, 'Pepsi': 1, 'Pringles': 1}
# {'Nutella': 1, 'Pepsi': 1, 'Pringles': 1}
